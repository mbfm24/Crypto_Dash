# %%
import pandas as pd
import streamlit as st
import sys
import datetime as dt
import os
import matplotlib.pyplot as plt
sys.path.append('./src/utils')
import data_loader_portfolio 
import constants
 
eth = pd.read_csv('./data/Ethereum.csv')

# %%
eth['date'] = pd.to_datetime(eth['date'])
eth = eth.drop(columns=['unix', 'open', 'high', 'low'])

# %%
import pandas as pd
import datetime as dt
returns_file = './clean_data/Bitcoin_clean.csv'
returns_data = pd.read_csv(returns_file, 
                           parse_dates=True, 
                           infer_datetime_format=True)

start_date = dt.datetime(2018, 1, 1)
end_date = dt.datetime(2023, 2, 1)
returns_data['date'] = pd.to_datetime(returns_data['date'])

# %%
eth.to_csv('./clean_data/Ethereum_clean.csv')

# %%
returns_data
# Out:
#                     date   symbol     close    Volume BTC    Volume USD  \
# 0    2023-02-01 00:00:00  BTC/USD  23715.81    462.534137  1.096937e+07
# 1    2023-01-31 00:00:00  BTC/USD  23138.09    371.243162  8.589858e+06
# 2    2023-01-30 00:00:00  BTC/USD  22829.24    498.139917  1.137216e+07
# 3    2023-01-29 00:00:00  BTC/USD  23761.08    335.619084  7.974672e+06
# 4    2023-01-28 00:00:00  BTC/USD  23031.37    132.820866  3.059047e+06
# ...                  ...      ...       ...           ...           ...
# 2206 2018-01-05 04:00:00  BTC/USD  16567.18  11124.264660  1.842977e+08
# 2207 2018-01-04 04:00:00  BTC/USD  14970.00  10517.033810  1.574400e+08
# 2208 2018-01-03 04:00:00  BTC/USD  15100.00   9989.680366  1.508442e+08
# 2209 2018-01-02 04:00:00  BTC/USD  14912.10   8890.250744  1.325723e+08
# 2210 2018-01-01 04:00:00  BTC/USD  13048.56   5430.363684  7.085843e+07
#
#       daily_return
# 0              NaN
# 1        -0.024360
# 2        -0.013348
# 3         0.040818
# ...
